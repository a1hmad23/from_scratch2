# %% [markdown]
# # Polynomial linear Regression
# In cases where the data is more complex than can be captured by drawing a straight line, we can still use a linear model to fit the data. The trick is to append our design matrix with powers of each feature, and then train a linear model on this extended set of features.

# %%
# Non-linear data
import numpy as np 

m = 100
x = 3 * np.random.randn(m, 1) - 4.6
y = 4 * np.random.randn(m, 1) - 2.3

z = 3 + 2 * x + y + 0.5 * X**2 + 0.4*y**2 + 3*x*y + 8 * np.random.randn(m, 1)

# %%
import plotly.express as px

fig = px.scatter_3d(
    x=x.ravel(),
    y=y.ravel(),
    z=z.ravel(),
    title="3D Polynomial Regression Data"
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 9
#       1 import plotly.express as px
#       3 fig = px.scatter_3d(
#       4     x=x.ravel(),
#       5     y=y.ravel(),
#       6     z=z.ravel(),
#       7     title="3D Polynomial Regression Data"
#       8 )
# ----> 9 fig.show()
#
# File D:\ml-projects\from_scratch2\venv\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File D:\ml-projects\from_scratch2\venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...
