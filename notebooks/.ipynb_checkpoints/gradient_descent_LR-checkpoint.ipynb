# %% [markdown]
# Given a design matrix (Each row in the first matrix, and each vector in the second matrix represent a training example)  $$
# \boldsymbol{X} = \begin{pmatrix}
# 1 & x_{11} & x_{12} & \dots & x_{1m} \\
# 1 & x_{21} & x_{22} & \dots & x_{2m} \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 1 & x_{n1} & x_{n2} & \dots & x_{nm}
# \end{pmatrix} = \begin{pmatrix}
# \vec{x_{1}}^T \\
# \vec{x_{2}}^T \\
# \vdots \\
# \vec{x_{n}}^T
# \end{pmatrix}
# $$and a target vector $$
# \boldsymbol{Y} = \begin{pmatrix}
# y_{1} \\
# y_{2} \\
# \vdots \\
# y_{n}
# \end{pmatrix} \hspace{0.1cm}\boldsymbol{,}
# $$
# we compute the augmented weight vector   $$
# \vec{\beta}=\begin{pmatrix}
# \beta_{0} \\
# \beta_{1} \\
# \vdots \\
# \beta_{m}
# \end{pmatrix}
# $$such that our model is $$
# \boldsymbol{\hat{Y}} = \boldsymbol{X} @ \vec{\beta}
# $$ where @ represents matrix multiplication.
#
# In explicit matrix form, we have $$
# \boldsymbol{\hat{Y}} = \begin{pmatrix}
# \beta_{0} + \beta_{1}x_{11}  + \dots + \beta_{m}x_{1m} \\
# \beta_{0} + \beta_{1}x_{21}  + \dots + \beta_{m}x_{2m} \\
# \vdots \\
# \beta_{0}+\beta_{1}x_{n1} + \dots _+ \beta_{m}x_{nm}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \vec{x_{1}}\cdot \vec{\beta} \\
# \vec{x_{2}} \cdot \vec{\beta} \\
# \vdots \\
# \vec{x_{n}} \cdot \vec{\beta}
# \end{pmatrix}
# $$
# ## Gradient Descent
# The **cost function** is $J = \sum_{i=0}^n(y_{i}-\hat{y}_{i})^2$  where $\hat{y}_{i}=\vec{x}_{1} \cdot \vec{\beta} =\sum_{j=0}^m\beta_{j}x_{j}$ .
# Thus, we have $$
# J(\vec{\beta}) =\frac{1}{2} \sum_{i=0}^n (y_{i} - \sum_{j=0}^m \beta_{j}x_{ij})^2
# $$
# lets compute the gradient $$
# \nabla J(\vec{\beta}) =  \frac{\partial J(\vec{\beta})}{\partial \vec{\beta}} = \begin{pmatrix}
# \frac{\partial J}{\partial \beta_{0}} \\
# \frac{\partial J}{\partial \beta_{1}} \\
# \vdots \\
# \frac{\partial J}{\partial \beta_{m}}
# \end{pmatrix}
# $$ lets compute the partial derivative of $J$ with respect to a arbitrary $\beta_{k}$ such that $0 \leq j \leq m$
# $$
# \frac{J(\vec{\beta})}{\partial \beta_{k}} = \sum_{i=0}^n (y_{i} - \sum_{j=0}^m \beta_{j}x_{ij}) x_{ik}
# $$
# since all the other terms in  $\sum_{j=0}^m\beta_{j}x_{j}$  are $0$ except $\beta_{k}x_{k}$ when differentiating with respect to $\beta_{k}$ .
#
# ### Steepest Descent
# *The gradient $\nabla J(\vec{\beta})$ gives the direction of steepest descent of the cost function. To see the intuition behind this, notice that each partial derivative tells you whether to move up or down along its axis.  The gradient combines those “binary” up/down decisions into the single direction that makes the cost increase most rapidly.*
#
# *To see why this gives the steepest ascent, imagine that for every parameter you can only make one of two choices — increase or decrease it. Each partial derivative tells you which of those two options will make the function grow along that specific dimension. When you put all those choices together, you get the direction where every coordinate contributes to increasing the function — the gradient direction.*
#
# *Any other combination of moves — for example, flipping the sign on one or two coordinates — would partially work _against_ the increase in those directions, so the overall rise would be slower. The gradient, therefore, encodes the most efficient “combination of moves” across all parameters to make the function grow as quickly as possible.*
#
# *Flipping all of those signs at once gives the exact opposite effect: every coordinate now works to decrease the function. This is the direction of **steepest descent**, the mirror image of the gradient, and the one used in gradient descent to reduce the cost most efficiently.*
#
# Thus, we update $\vec{\beta}$  in the direction of the steepest descent of the cost function:
# $$
# \vec{\beta}=\vec{\beta} - \alpha\frac{\partial J}{\partial\vec{\beta}}
# $$
# Or, for $0\leq k\leq m$ ,$$
# \beta_{k} = \beta_{k} - \alpha   \sum_{i=0}^n (y_{i} - \sum_{j=0}^m \beta_{j}x_{ij}) x_{ik}
# $$ here $\alpha > 0$ is the learning rate.
#
# Upon inspection of the above equation, we can arrive at the following vectorized form:
# $$
# \vec{\beta} = \vec{\beta} - \alpha\boldsymbol{X}^T(\boldsymbol{Y} - \boldsymbol{X} @  \vec{\beta})
# $$

# %%
import numpy as np
from numpy.typing import ArrayLike

class GDLinearRegressor:
    def __init__(self, learning_rate: float = 0.01, epochs: int = 200):
        self.alpha = learning_rate
        self.epochs = epochs
        self.beta = None
        self.m = None

    def _validate_input(self, X, y=None):
        """Internal helper for checking and preparing input arrays."""
        X = np.asarray(X, dtype=float)
    
        # If y is provided (fit case)
        if y is not None:
            y = np.asarray(y, dtype=float).reshape(-1, 1)
    
            if X.size == 0 or y.size == 0:
                raise ValueError("X and y must be non-empty.")
            if X.shape[0] != y.shape[0]:
                raise ValueError("X and y must have the same number of samples.")
            if not np.isfinite(X).all() or not np.isfinite(y).all():
                raise ValueError("Inputs contain NaN or infinite values.")
    
        else:
            # Only validate X (predict case)
            if X.size == 0:
                raise ValueError("X must be non-empty.")
            if not np.isfinite(X).all():
                raise ValueError("X contains NaN or infinite values.")
    
        if X.ndim == 1:
            X = X.reshape(-1, 1)
    
        # Return both for fit(), only X for predict()
        return (X, y) if y is not None else X

    def fit(self, X_train: ArrayLike, y_train: ArrayLike):
        X, y = self._validate_input(X_train, y_train)
        n, self.m = X.shape
        X_c = np.concatenate((np.ones((n, 1)), X), axis=1)
        self.beta = np.zeros((self.m + 1, 1))
    
        for _ in range(self.epochs):
            grad = -(X_c.T @ (y - X_c @ self.beta)) / n
            self.beta -= self.alpha * grad
            if _ % 1 == 0:
                cost = np.mean((y - X_c @ self.beta) ** 2)
                print(f"Epoch {_}: cost = {cost:.4f}")

        return self
        
    def predict(self, X_test: ArrayLike):

        if self.beta is None:
            raise ValueError("Model has not been fitted yet.")
        
        X = self._validate_input(X_test) 
        n = X.shape[0]
        X_c = np.concatenate((np.ones((n, 1)), X), axis=1)
        return X_c @ self.beta

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=100, n_features=5, n_informative=5, n_targets=1, noise=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
gd_lr = GDLinearRegressor(0.01, 1500)
gd_lr.fit(X_train, y_train)
# Out:
# Epoch 0: cost = 10969.3262
# Epoch 1: cost = 10706.0265
# Epoch 2: cost = 10449.3157
# Epoch 3: cost = 10199.0224
# Epoch 4: cost = 9954.9804
# Epoch 5: cost = 9717.0274
# Epoch 6: cost = 9485.0059
# Epoch 7: cost = 9258.7622
# Epoch 8: cost = 9038.1470
# Epoch 9: cost = 8823.0150
# Epoch 10: cost = 8613.2245
# Epoch 11: cost = 8408.6378
# Epoch 12: cost = 8209.1208
# Epoch 13: cost = 8014.5431
# Epoch 14: cost = 7824.7775
# Epoch 15: cost = 7639.7004
# Epoch 16: cost = 7459.1914
# Epoch 17: cost = 7283.1333
# Epoch 18: cost = 7111.4120
# Epoch 19: cost = 6943.9166
# Epoch 20: cost = 6780.5388
# Epoch 21: cost = 6621.1734
# Epoch 22: cost = 6465.7179
# Epoch 23: cost = 6314.0726
# Epoch 24: cost = 6166.1404
# Epoch 25: cost = 6021.8266
# Epoch 26: cost = 5881.0392
# Epoch 27: cost = 5743.6886
# Epoch 28: cost = 5609.6874
# Epoch 29: cost = 5478.9507
# Epoch 30: cost = 5351.3956
# Epoch 31: cost = 5226.9417
# Epoch 32: cost = 5105.5103
# Epoch 33: cost = 4987.0252
# Epoch 34: cost = 4871.4118
# Epoch 35: cost = 4758.5978
# Epoch 36: cost = 4648.5125
# Epoch 37: cost = 4541.0872
# Epoch 38: cost = 4436.2549
# Epoch 39: cost = 4333.9506
# Epoch 40: cost = 4234.1106
# Epoch 41: cost = 4136.6732
# Epoch 42: cost = 4041.5781
# Epoch 43: cost = 3948.7666
# Epoch 44: cost = 3858.1817
# Epoch 45: cost = 3769.7676
# Epoch 46: cost = 3683.4702
# Epoch 47: cost = 3599.2366
# Epoch 48: cost = 3517.0154
# Epoch 49: cost = 3436.7564
# Epoch 50: cost = 3358.4110
# Epoch 51: cost = 3281.9314
# Epoch 52: cost = 3207.2715
# Epoch 53: cost = 3134.3859
# Epoch 54: cost = 3063.2309
# Epoch 55: cost = 2993.7635
# Epoch 56: cost = 2925.9420
# Epoch 57: cost = 2859.7257
# Epoch 58: cost = 2795.0751
# Epoch 59: cost = 2731.9515
# Epoch 60: cost = 2670.3172
# Epoch 61: cost = 2610.1357
# Epoch 62: cost = 2551.3712
# Epoch 63: cost = 2493.9889
# Epoch 64: cost = 2437.9549
# Epoch 65: cost = 2383.2362
# Epoch 66: cost = 2329.8005
# Epoch 67: cost = 2277.6164
# Epoch 68: cost = 2226.6534
# Epoch 69: cost = 2176.8817
# Epoch 70: cost = 2128.2722
# Epoch 71: cost = 2080.7965
# Epoch 72: cost = 2034.4271
# Epoch 73: cost = 1989.1371
# Epoch 74: cost = 1944.9003
# Epoch 75: cost = 1901.6910
# Epoch 76: cost = 1859.4844
# Epoch 77: cost = 1818.2563
# Epoch 78: cost = 1777.9828
# Epoch 79: cost = 1738.6411
# Epoch 80: cost = 1700.2084
# Epoch 81: cost = 1662.6630
# Epoch 82: cost = 1625.9835
# Epoch 83: cost = 1590.1490
# Epoch 84: cost = 1555.1391
# Epoch 85: cost = 1520.9341
# Epoch 86: cost = 1487.5147
# Epoch 87: cost = 1454.8620
# Epoch 88: cost = 1422.9577
# Epoch 89: cost = 1391.7839
# Epoch 90: cost = 1361.3230
# Epoch 91: cost = 1331.5581
# Epoch 92: cost = 1302.4726
# Epoch 93: cost = 1274.0503
# Epoch 94: cost = 1246.2754
# Epoch 95: cost = 1219.1325
# Epoch 96: cost = 1192.6066
# Epoch 97: cost = 1166.6831
# Epoch 98: cost = 1141.3476
# Epoch 99: cost = 1116.5863
# Epoch 100: cost = 1092.3856
# Epoch 101: cost = 1068.7322
# Epoch 102: cost = 1045.6131
# Epoch 103: cost = 1023.0159
# Epoch 104: cost = 1000.9282
# Epoch 105: cost = 979.3380
# Epoch 106: cost = 958.2336
# Epoch 107: cost = 937.6036
# Epoch 108: cost = 917.4369
# Epoch 109: cost = 897.7226
# Epoch 110: cost = 878.4502
# Epoch 111: cost = 859.6092
# Epoch 112: cost = 841.1896
# Epoch 113: cost = 823.1816
# Epoch 114: cost = 805.5756
# Epoch 115: cost = 788.3621
# Epoch 116: cost = 771.5322
# Epoch 117: cost = 755.0768
# Epoch 118: cost = 738.9873
# Epoch 119: cost = 723.2551
# Epoch 120: cost = 707.8720
# Epoch 121: cost = 692.8300
# Epoch 122: cost = 678.1210
# Epoch 123: cost = 663.7375
# Epoch 124: cost = 649.6719
# Epoch 125: cost = 635.9169
# Epoch 126: cost = 622.4653
# Epoch 127: cost = 609.3102
# Epoch 128: cost = 596.4446
# Epoch 129: cost = 583.8621
# Epoch 130: cost = 571.5561
# Epoch 131: cost = 559.5202
# Epoch 132: cost = 547.7483
# Epoch 133: cost = 536.2343
# Epoch 134: cost = 524.9724
# Epoch 135: cost = 513.9567
# Epoch 136: cost = 503.1818
# Epoch 137: cost = 492.6420
# Epoch 138: cost = 482.3320
# Epoch 139: cost = 472.2467
# Epoch 140: cost = 462.3809
# Epoch 141: cost = 452.7296
# Epoch 142: cost = 443.2880
# Epoch 143: cost = 434.0513
# Epoch 144: cost = 425.0149
# Epoch 145: cost = 416.1743
# Epoch 146: cost = 407.5250
# Epoch 147: cost = 399.0628
# Epoch 148: cost = 390.7833
# Epoch 149: cost = 382.6826
# Epoch 150: cost = 374.7566
# Epoch 151: cost = 367.0013
# Epoch 152: cost = 359.4129
# Epoch 153: cost = 351.9878
# Epoch 154: cost = 344.7222
# Epoch 155: cost = 337.6125
# Epoch 156: cost = 330.6553
# Epoch 157: cost = 323.8472
# Epoch 158: cost = 317.1849
# Epoch 159: cost = 310.6650
# Epoch 160: cost = 304.2845
# Epoch 161: cost = 298.0403
# Epoch 162: cost = 291.9292
# Epoch 163: cost = 285.9484
# Epoch 164: cost = 280.0949
# Epoch 165: cost = 274.3660
# Epoch 166: cost = 268.7588
# Epoch 167: cost = 263.2708
# Epoch 168: cost = 257.8992
# Epoch 169: cost = 252.6415
# Epoch 170: cost = 247.4952
# Epoch 171: cost = 242.4578
# Epoch 172: cost = 237.5269
# Epoch 173: cost = 232.7003
# Epoch 174: cost = 227.9755
# Epoch 175: cost = 223.3504
# Epoch 176: cost = 218.8227
# Epoch 177: cost = 214.3904
# Epoch 178: cost = 210.0514
# Epoch 179: cost = 205.8036
# Epoch 180: cost = 201.6450
# Epoch 181: cost = 197.5737
# Epoch 182: cost = 193.5877
# Epoch 183: cost = 189.6853
# Epoch 184: cost = 185.8646
# Epoch 185: cost = 182.1238
# Epoch 186: cost = 178.4612
# Epoch 187: cost = 174.8751
# Epoch 188: cost = 171.3638
# Epoch 189: cost = 167.9258
# Epoch 190: cost = 164.5594
# Epoch 191: cost = 161.2630
# Epoch 192: cost = 158.0352
# Epoch 193: cost = 154.8745
# Epoch 194: cost = 151.7795
# Epoch 195: cost = 148.7487
# Epoch 196: cost = 145.7807
# Epoch 197: cost = 142.8742
# Epoch 198: cost = 140.0279
# Epoch 199: cost = 137.2405
# Epoch 200: cost = 134.5106
# Epoch 201: cost = 131.8372
# Epoch 202: cost = 129.2190
# Epoch 203: cost = 126.6547
# Epoch 204: cost = 124.1433
# Epoch 205: cost = 121.6836
# Epoch 206: cost = 119.2745
# Epoch 207: cost = 116.9150
# Epoch 208: cost = 114.6039
# Epoch 209: cost = 112.3403
# Epoch 210: cost = 110.1231
# Epoch 211: cost = 107.9514
# Epoch 212: cost = 105.8242
# Epoch 213: cost = 103.7405
# Epoch 214: cost = 101.6994
# Epoch 215: cost = 99.7000
# Epoch 216: cost = 97.7415
# Epoch 217: cost = 95.8230
# Epoch 218: cost = 93.9436
# Epoch 219: cost = 92.1025
# Epoch 220: cost = 90.2989
# Epoch 221: cost = 88.5320
# Epoch 222: cost = 86.8010
# Epoch 223: cost = 85.1052
# Epoch 224: cost = 83.4439
# Epoch 225: cost = 81.8163
# Epoch 226: cost = 80.2217
# Epoch 227: cost = 78.6594
# Epoch 228: cost = 77.1287
# Epoch 229: cost = 75.6291
# Epoch 230: cost = 74.1597
# Epoch 231: cost = 72.7201
# Epoch 232: cost = 71.3095
# Epoch 233: cost = 69.9274
# Epoch 234: cost = 68.5732
# Epoch 235: cost = 67.2463
# Epoch 236: cost = 65.9461
# Epoch 237: cost = 64.6721
# Epoch 238: cost = 63.4237
# Epoch 239: cost = 62.2005
# Epoch 240: cost = 61.0018
# Epoch 241: cost = 59.8271
# Epoch 242: cost = 58.6761
# Epoch 243: cost = 57.5481
# Epoch 244: cost = 56.4427
# Epoch 245: cost = 55.3595
# Epoch 246: cost = 54.2980
# Epoch 247: cost = 53.2576
# Epoch 248: cost = 52.2381
# Epoch 249: cost = 51.2390
# Epoch 250: cost = 50.2598
# Epoch 251: cost = 49.3001
# Epoch 252: cost = 48.3596
# Epoch 253: cost = 47.4378
# Epoch 254: cost = 46.5343
# Epoch 255: cost = 45.6489
# Epoch 256: cost = 44.7811
# Epoch 257: cost = 43.9305
# Epoch 258: cost = 43.0968
# Epoch 259: cost = 42.2797
# Epoch 260: cost = 41.4787
# Epoch 261: cost = 40.6937
# Epoch 262: cost = 39.9242
# Epoch 263: cost = 39.1700
# Epoch 264: cost = 38.4307
# Epoch 265: cost = 37.7060
# Epoch 266: cost = 36.9957
# Epoch 267: cost = 36.2994
# Epoch 268: cost = 35.6169
# Epoch 269: cost = 34.9478
# Epoch 270: cost = 34.2919
# Epoch 271: cost = 33.6490
# Epoch 272: cost = 33.0187
# Epoch 273: cost = 32.4009
# Epoch 274: cost = 31.7952
# Epoch 275: cost = 31.2014
# Epoch 276: cost = 30.6193
# Epoch 277: cost = 30.0487
# Epoch 278: cost = 29.4892
# Epoch 279: cost = 28.9407
# Epoch 280: cost = 28.4030
# Epoch 281: cost = 27.8759
# Epoch 282: cost = 27.3591
# Epoch 283: cost = 26.8524
# Epoch 284: cost = 26.3556
# Epoch 285: cost = 25.8685
# Epoch 286: cost = 25.3910
# Epoch 287: cost = 24.9228
# Epoch 288: cost = 24.4638
# Epoch 289: cost = 24.0137
# Epoch 290: cost = 23.5724
# Epoch 291: cost = 23.1397
# Epoch 292: cost = 22.7155
# Epoch 293: cost = 22.2995
# Epoch 294: cost = 21.8916
# Epoch 295: cost = 21.4917
# Epoch 296: cost = 21.0995
# Epoch 297: cost = 20.7150
# Epoch 298: cost = 20.3379
# Epoch 299: cost = 19.9682
# Epoch 300: cost = 19.6057
# Epoch 301: cost = 19.2502
# Epoch 302: cost = 18.9015
# Epoch 303: cost = 18.5597
# Epoch 304: cost = 18.2245
# Epoch 305: cost = 17.8957
# Epoch 306: cost = 17.5734
# Epoch 307: cost = 17.2573
# Epoch 308: cost = 16.9473
# Epoch 309: cost = 16.6433
# Epoch 310: cost = 16.3451
# Epoch 311: cost = 16.0528
# Epoch 312: cost = 15.7660
# Epoch 313: cost = 15.4848
# Epoch 314: cost = 15.2091
# Epoch 315: cost = 14.9386
# Epoch 316: cost = 14.6734
# Epoch 317: cost = 14.4133
# Epoch 318: cost = 14.1581
# Epoch 319: cost = 13.9079
# Epoch 320: cost = 13.6626
# Epoch 321: cost = 13.4219
# Epoch 322: cost = 13.1858
# Epoch 323: cost = 12.9543
# Epoch 324: cost = 12.7273
# Epoch 325: cost = 12.5046
# Epoch 326: cost = 12.2862
# Epoch 327: cost = 12.0719
# Epoch 328: cost = 11.8618
# Epoch 329: cost = 11.6557
# Epoch 330: cost = 11.4535
# Epoch 331: cost = 11.2553
# Epoch 332: cost = 11.0608
# Epoch 333: cost = 10.8700
# Epoch 334: cost = 10.6829
# Epoch 335: cost = 10.4994
# Epoch 336: cost = 10.3193
# Epoch 337: cost = 10.1428
# Epoch 338: cost = 9.9695
# Epoch 339: cost = 9.7996
# Epoch 340: cost = 9.6330
# Epoch 341: cost = 9.4695
# Epoch 342: cost = 9.3091
# Epoch 343: cost = 9.1518
# Epoch 344: cost = 8.9975
# Epoch 345: cost = 8.8461
# Epoch 346: cost = 8.6976
# Epoch 347: cost = 8.5519
# Epoch 348: cost = 8.4090
# Epoch 349: cost = 8.2688
# Epoch 350: cost = 8.1313
# Epoch 351: cost = 7.9964
# Epoch 352: cost = 7.8641
# Epoch 353: cost = 7.7342
# Epoch 354: cost = 7.6069
# Epoch 355: cost = 7.4819
# Epoch 356: cost = 7.3593
# Epoch 357: cost = 7.2391
# Epoch 358: cost = 7.1211
# Epoch 359: cost = 7.0053
# Epoch 360: cost = 6.8918
# Epoch 361: cost = 6.7804
# Epoch 362: cost = 6.6711
# Epoch 363: cost = 6.5639
# Epoch 364: cost = 6.4587
# Epoch 365: cost = 6.3554
# Epoch 366: cost = 6.2542
# Epoch 367: cost = 6.1548
# Epoch 368: cost = 6.0574
# Epoch 369: cost = 5.9617
# Epoch 370: cost = 5.8679
# Epoch 371: cost = 5.7758
# Epoch 372: cost = 5.6855
# Epoch 373: cost = 5.5969
# Epoch 374: cost = 5.5099
# Epoch 375: cost = 5.4246
# Epoch 376: cost = 5.3409
# Epoch 377: cost = 5.2588
# Epoch 378: cost = 5.1782
# Epoch 379: cost = 5.0991
# Epoch 380: cost = 5.0216
# Epoch 381: cost = 4.9454
# Epoch 382: cost = 4.8707
# Epoch 383: cost = 4.7974
# Epoch 384: cost = 4.7255
# Epoch 385: cost = 4.6550
# Epoch 386: cost = 4.5857
# Epoch 387: cost = 4.5178
# Epoch 388: cost = 4.4511
# Epoch 389: cost = 4.3857
# Epoch 390: cost = 4.3215
# Epoch 391: cost = 4.2585
# Epoch 392: cost = 4.1967
# Epoch 393: cost = 4.1361
# Epoch 394: cost = 4.0765
# Epoch 395: cost = 4.0181
# Epoch 396: cost = 3.9608
# Epoch 397: cost = 3.9046
# Epoch 398: cost = 3.8494
# Epoch 399: cost = 3.7953
# Epoch 400: cost = 3.7421
# Epoch 401: cost = 3.6900
# Epoch 402: cost = 3.6388
# Epoch 403: cost = 3.5886
# Epoch 404: cost = 3.5393
# Epoch 405: cost = 3.4909
# Epoch 406: cost = 3.4435
# Epoch 407: cost = 3.3969
# Epoch 408: cost = 3.3512
# Epoch 409: cost = 3.3063
# Epoch 410: cost = 3.2623
# Epoch 411: cost = 3.2191
# Epoch 412: cost = 3.1767
# Epoch 413: cost = 3.1351
# Epoch 414: cost = 3.0943
# Epoch 415: cost = 3.0542
# Epoch 416: cost = 3.0149
# Epoch 417: cost = 2.9763
# Epoch 418: cost = 2.9384
# Epoch 419: cost = 2.9012
# Epoch 420: cost = 2.8647
# Epoch 421: cost = 2.8289
# Epoch 422: cost = 2.7938
# Epoch 423: cost = 2.7593
# Epoch 424: cost = 2.7255
# Epoch 425: cost = 2.6922
# Epoch 426: cost = 2.6596
# Epoch 427: cost = 2.6276
# Epoch 428: cost = 2.5962
# Epoch 429: cost = 2.5654
# Epoch 430: cost = 2.5351
# Epoch 431: cost = 2.5055
# Epoch 432: cost = 2.4763
# Epoch 433: cost = 2.4477
# Epoch 434: cost = 2.4196
# Epoch 435: cost = 2.3921
# Epoch 436: cost = 2.3650
# Epoch 437: cost = 2.3385
# Epoch 438: cost = 2.3124
# Epoch 439: cost = 2.2869
# Epoch 440: cost = 2.2618
# Epoch 441: cost = 2.2371
# Epoch 442: cost = 2.2129
# Epoch 443: cost = 2.1892
# Epoch 444: cost = 2.1659
# Epoch 445: cost = 2.1430
# Epoch 446: cost = 2.1206
# Epoch 447: cost = 2.0986
# Epoch 448: cost = 2.0769
# Epoch 449: cost = 2.0557
# Epoch 450: cost = 2.0349
# Epoch 451: cost = 2.0144
# Epoch 452: cost = 1.9944
# Epoch 453: cost = 1.9747
# Epoch 454: cost = 1.9553
# Epoch 455: cost = 1.9363
# Epoch 456: cost = 1.9177
# Epoch 457: cost = 1.8994
# Epoch 458: cost = 1.8814
# Epoch 459: cost = 1.8638
# Epoch 460: cost = 1.8465
# Epoch 461: cost = 1.8295
# Epoch 462: cost = 1.8129
# Epoch 463: cost = 1.7965
# Epoch 464: cost = 1.7804
# Epoch 465: cost = 1.7647
# Epoch 466: cost = 1.7492
# Epoch 467: cost = 1.7340
# Epoch 468: cost = 1.7191
# Epoch 469: cost = 1.7044
# Epoch 470: cost = 1.6901
# Epoch 471: cost = 1.6759
# Epoch 472: cost = 1.6621
# Epoch 473: cost = 1.6485
# Epoch 474: cost = 1.6351
# Epoch 475: cost = 1.6220
# Epoch 476: cost = 1.6092
# Epoch 477: cost = 1.5965
# Epoch 478: cost = 1.5842
# Epoch 479: cost = 1.5720
# Epoch 480: cost = 1.5600
# Epoch 481: cost = 1.5483
# Epoch 482: cost = 1.5368
# Epoch 483: cost = 1.5255
# Epoch 484: cost = 1.5144
# Epoch 485: cost = 1.5035
# Epoch 486: cost = 1.4928
# Epoch 487: cost = 1.4823
# Epoch 488: cost = 1.4720
# Epoch 489: cost = 1.4619
# Epoch 490: cost = 1.4520
# Epoch 491: cost = 1.4422
# Epoch 492: cost = 1.4326
# Epoch 493: cost = 1.4232
# Epoch 494: cost = 1.4140
# Epoch 495: cost = 1.4049
# Epoch 496: cost = 1.3960
# Epoch 497: cost = 1.3873
# Epoch 498: cost = 1.3787
# Epoch 499: cost = 1.3703
# Epoch 500: cost = 1.3621
# Epoch 501: cost = 1.3539
# Epoch 502: cost = 1.3460
# Epoch 503: cost = 1.3382
# Epoch 504: cost = 1.3305
# Epoch 505: cost = 1.3230
# Epoch 506: cost = 1.3156
# Epoch 507: cost = 1.3083
# Epoch 508: cost = 1.3012
# Epoch 509: cost = 1.2942
# Epoch 510: cost = 1.2873
# Epoch 511: cost = 1.2805
# Epoch 512: cost = 1.2739
# Epoch 513: cost = 1.2674
# Epoch 514: cost = 1.2610
# Epoch 515: cost = 1.2547
# Epoch 516: cost = 1.2486
# Epoch 517: cost = 1.2425
# Epoch 518: cost = 1.2366
# Epoch 519: cost = 1.2308
# Epoch 520: cost = 1.2250
# Epoch 521: cost = 1.2194
# Epoch 522: cost = 1.2139
# Epoch 523: cost = 1.2085
# Epoch 524: cost = 1.2032
# Epoch 525: cost = 1.1979
# Epoch 526: cost = 1.1928
# Epoch 527: cost = 1.1878
# Epoch 528: cost = 1.1828
# Epoch 529: cost = 1.1780
# Epoch 530: cost = 1.1732
# Epoch 531: cost = 1.1685
# Epoch 532: cost = 1.1639
# Epoch 533: cost = 1.1594
# Epoch 534: cost = 1.1550
# Epoch 535: cost = 1.1506
# Epoch 536: cost = 1.1464
# Epoch 537: cost = 1.1422
# Epoch 538: cost = 1.1381
# Epoch 539: cost = 1.1340
# Epoch 540: cost = 1.1301
# Epoch 541: cost = 1.1262
# Epoch 542: cost = 1.1223
# Epoch 543: cost = 1.1186
# Epoch 544: cost = 1.1149
# Epoch 545: cost = 1.1113
# Epoch 546: cost = 1.1077
# Epoch 547: cost = 1.1042
# Epoch 548: cost = 1.1008
# Epoch 549: cost = 1.0974
# Epoch 550: cost = 1.0941
# Epoch 551: cost = 1.0908
# Epoch 552: cost = 1.0877
# Epoch 553: cost = 1.0845
# Epoch 554: cost = 1.0814
# Epoch 555: cost = 1.0784
# Epoch 556: cost = 1.0755
# Epoch 557: cost = 1.0726
# Epoch 558: cost = 1.0697
# Epoch 559: cost = 1.0669
# Epoch 560: cost = 1.0641
# Epoch 561: cost = 1.0614
# Epoch 562: cost = 1.0588
# Epoch 563: cost = 1.0561
# Epoch 564: cost = 1.0536
# Epoch 565: cost = 1.0511
# Epoch 566: cost = 1.0486
# Epoch 567: cost = 1.0462
# Epoch 568: cost = 1.0438
# Epoch 569: cost = 1.0414
# Epoch 570: cost = 1.0391
# Epoch 571: cost = 1.0369
# Epoch 572: cost = 1.0347
# Epoch 573: cost = 1.0325
# Epoch 574: cost = 1.0304
# Epoch 575: cost = 1.0283
# Epoch 576: cost = 1.0262
# Epoch 577: cost = 1.0242
# Epoch 578: cost = 1.0222
# Epoch 579: cost = 1.0202
# Epoch 580: cost = 1.0183
# Epoch 581: cost = 1.0164
# Epoch 582: cost = 1.0146
# Epoch 583: cost = 1.0128
# Epoch 584: cost = 1.0110
# Epoch 585: cost = 1.0092
# Epoch 586: cost = 1.0075
# Epoch 587: cost = 1.0058
# Epoch 588: cost = 1.0042
# Epoch 589: cost = 1.0025
# Epoch 590: cost = 1.0009
# Epoch 591: cost = 0.9994
# Epoch 592: cost = 0.9978
# Epoch 593: cost = 0.9963
# Epoch 594: cost = 0.9948
# Epoch 595: cost = 0.9934
# Epoch 596: cost = 0.9919
# Epoch 597: cost = 0.9905
# Epoch 598: cost = 0.9891
# Epoch 599: cost = 0.9878
# Epoch 600: cost = 0.9864
# Epoch 601: cost = 0.9851
# Epoch 602: cost = 0.9838
# Epoch 603: cost = 0.9826
# Epoch 604: cost = 0.9813
# Epoch 605: cost = 0.9801
# Epoch 606: cost = 0.9789
# Epoch 607: cost = 0.9777
# Epoch 608: cost = 0.9766
# Epoch 609: cost = 0.9754
# Epoch 610: cost = 0.9743
# Epoch 611: cost = 0.9732
# Epoch 612: cost = 0.9722
# Epoch 613: cost = 0.9711
# Epoch 614: cost = 0.9701
# Epoch 615: cost = 0.9691
# Epoch 616: cost = 0.9681
# Epoch 617: cost = 0.9671
# Epoch 618: cost = 0.9661
# Epoch 619: cost = 0.9652
# Epoch 620: cost = 0.9642
# Epoch 621: cost = 0.9633
# Epoch 622: cost = 0.9624
# Epoch 623: cost = 0.9615
# Epoch 624: cost = 0.9607
# Epoch 625: cost = 0.9598
# Epoch 626: cost = 0.9590
# Epoch 627: cost = 0.9582
# Epoch 628: cost = 0.9574
# Epoch 629: cost = 0.9566
# Epoch 630: cost = 0.9558
# Epoch 631: cost = 0.9550
# Epoch 632: cost = 0.9543
# Epoch 633: cost = 0.9535
# Epoch 634: cost = 0.9528
# Epoch 635: cost = 0.9521
# Epoch 636: cost = 0.9514
# Epoch 637: cost = 0.9507
# Epoch 638: cost = 0.9501
# Epoch 639: cost = 0.9494
# Epoch 640: cost = 0.9487
# Epoch 641: cost = 0.9481
# Epoch 642: cost = 0.9475
# Epoch 643: cost = 0.9469
# Epoch 644: cost = 0.9463
# Epoch 645: cost = 0.9457
# Epoch 646: cost = 0.9451
# Epoch 647: cost = 0.9445
# Epoch 648: cost = 0.9440
# Epoch 649: cost = 0.9434
# Epoch 650: cost = 0.9429
# Epoch 651: cost = 0.9423
# Epoch 652: cost = 0.9418
# Epoch 653: cost = 0.9413
# Epoch 654: cost = 0.9408
# Epoch 655: cost = 0.9403
# Epoch 656: cost = 0.9398
# Epoch 657: cost = 0.9393
# Epoch 658: cost = 0.9389
# Epoch 659: cost = 0.9384
# Epoch 660: cost = 0.9379
# Epoch 661: cost = 0.9375
# Epoch 662: cost = 0.9371
# Epoch 663: cost = 0.9366
# Epoch 664: cost = 0.9362
# Epoch 665: cost = 0.9358
# Epoch 666: cost = 0.9354
# Epoch 667: cost = 0.9350
# Epoch 668: cost = 0.9346
# Epoch 669: cost = 0.9342
# Epoch 670: cost = 0.9338
# Epoch 671: cost = 0.9335
# Epoch 672: cost = 0.9331
# Epoch 673: cost = 0.9327
# Epoch 674: cost = 0.9324
# Epoch 675: cost = 0.9320
# Epoch 676: cost = 0.9317
# Epoch 677: cost = 0.9314
# Epoch 678: cost = 0.9310
# Epoch 679: cost = 0.9307
# Epoch 680: cost = 0.9304
# Epoch 681: cost = 0.9301
# Epoch 682: cost = 0.9298
# Epoch 683: cost = 0.9295
# Epoch 684: cost = 0.9292
# Epoch 685: cost = 0.9289
# Epoch 686: cost = 0.9286
# Epoch 687: cost = 0.9283
# Epoch 688: cost = 0.9281
# Epoch 689: cost = 0.9278
# Epoch 690: cost = 0.9275
# Epoch 691: cost = 0.9273
# Epoch 692: cost = 0.9270
# Epoch 693: cost = 0.9267
# Epoch 694: cost = 0.9265
# Epoch 695: cost = 0.9263
# Epoch 696: cost = 0.9260
# Epoch 697: cost = 0.9258
# Epoch 698: cost = 0.9256
# Epoch 699: cost = 0.9253
# Epoch 700: cost = 0.9251
# Epoch 701: cost = 0.9249
# Epoch 702: cost = 0.9247
# Epoch 703: cost = 0.9245
# Epoch 704: cost = 0.9243
# Epoch 705: cost = 0.9241
# Epoch 706: cost = 0.9239
# Epoch 707: cost = 0.9237
# Epoch 708: cost = 0.9235
# Epoch 709: cost = 0.9233
# Epoch 710: cost = 0.9231
# Epoch 711: cost = 0.9229
# Epoch 712: cost = 0.9227
# Epoch 713: cost = 0.9226
# Epoch 714: cost = 0.9224
# Epoch 715: cost = 0.9222
# Epoch 716: cost = 0.9221
# Epoch 717: cost = 0.9219
# Epoch 718: cost = 0.9217
# Epoch 719: cost = 0.9216
# Epoch 720: cost = 0.9214
# Epoch 721: cost = 0.9213
# Epoch 722: cost = 0.9211
# Epoch 723: cost = 0.9210
# Epoch 724: cost = 0.9208
# Epoch 725: cost = 0.9207
# Epoch 726: cost = 0.9205
# Epoch 727: cost = 0.9204
# Epoch 728: cost = 0.9203
# Epoch 729: cost = 0.9201
# Epoch 730: cost = 0.9200
# Epoch 731: cost = 0.9199
# Epoch 732: cost = 0.9198
# Epoch 733: cost = 0.9196
# Epoch 734: cost = 0.9195
# Epoch 735: cost = 0.9194
# Epoch 736: cost = 0.9193
# Epoch 737: cost = 0.9192
# Epoch 738: cost = 0.9190
# Epoch 739: cost = 0.9189
# Epoch 740: cost = 0.9188
# Epoch 741: cost = 0.9187
# Epoch 742: cost = 0.9186
# Epoch 743: cost = 0.9185
# Epoch 744: cost = 0.9184
# Epoch 745: cost = 0.9183
# Epoch 746: cost = 0.9182
# Epoch 747: cost = 0.9181
# Epoch 748: cost = 0.9180
# Epoch 749: cost = 0.9179
# Epoch 750: cost = 0.9178
# Epoch 751: cost = 0.9177
# Epoch 752: cost = 0.9177
# Epoch 753: cost = 0.9176
# Epoch 754: cost = 0.9175
# Epoch 755: cost = 0.9174
# Epoch 756: cost = 0.9173
# Epoch 757: cost = 0.9172
# Epoch 758: cost = 0.9172
# Epoch 759: cost = 0.9171
# Epoch 760: cost = 0.9170
# Epoch 761: cost = 0.9169
# Epoch 762: cost = 0.9169
# Epoch 763: cost = 0.9168
# Epoch 764: cost = 0.9167
# Epoch 765: cost = 0.9166
# Epoch 766: cost = 0.9166
# Epoch 767: cost = 0.9165
# Epoch 768: cost = 0.9164
# Epoch 769: cost = 0.9164
# Epoch 770: cost = 0.9163
# Epoch 771: cost = 0.9163
# Epoch 772: cost = 0.9162
# Epoch 773: cost = 0.9161
# Epoch 774: cost = 0.9161
# Epoch 775: cost = 0.9160
# Epoch 776: cost = 0.9160
# Epoch 777: cost = 0.9159
# Epoch 778: cost = 0.9158
# Epoch 779: cost = 0.9158
# Epoch 780: cost = 0.9157
# Epoch 781: cost = 0.9157
# Epoch 782: cost = 0.9156
# Epoch 783: cost = 0.9156
# Epoch 784: cost = 0.9155
# Epoch 785: cost = 0.9155
# Epoch 786: cost = 0.9154
# Epoch 787: cost = 0.9154
# Epoch 788: cost = 0.9153
# Epoch 789: cost = 0.9153
# Epoch 790: cost = 0.9153
# Epoch 791: cost = 0.9152
# Epoch 792: cost = 0.9152
# Epoch 793: cost = 0.9151
# Epoch 794: cost = 0.9151
# Epoch 795: cost = 0.9150
# Epoch 796: cost = 0.9150
# Epoch 797: cost = 0.9150
# Epoch 798: cost = 0.9149
# Epoch 799: cost = 0.9149
# Epoch 800: cost = 0.9148
# Epoch 801: cost = 0.9148
# Epoch 802: cost = 0.9148
# Epoch 803: cost = 0.9147
# Epoch 804: cost = 0.9147
# Epoch 805: cost = 0.9147
# Epoch 806: cost = 0.9146
# Epoch 807: cost = 0.9146
# Epoch 808: cost = 0.9146
# Epoch 809: cost = 0.9145
# Epoch 810: cost = 0.9145
# Epoch 811: cost = 0.9145
# Epoch 812: cost = 0.9144
# Epoch 813: cost = 0.9144
# Epoch 814: cost = 0.9144
# Epoch 815: cost = 0.9144
# Epoch 816: cost = 0.9143
# Epoch 817: cost = 0.9143
# Epoch 818: cost = 0.9143
# Epoch 819: cost = 0.9142
# Epoch 820: cost = 0.9142
# Epoch 821: cost = 0.9142
# Epoch 822: cost = 0.9142
# Epoch 823: cost = 0.9141
# Epoch 824: cost = 0.9141
# Epoch 825: cost = 0.9141
# Epoch 826: cost = 0.9141
# Epoch 827: cost = 0.9140
# Epoch 828: cost = 0.9140
# Epoch 829: cost = 0.9140
# Epoch 830: cost = 0.9140
# Epoch 831: cost = 0.9140
# Epoch 832: cost = 0.9139
# Epoch 833: cost = 0.9139
# Epoch 834: cost = 0.9139
# Epoch 835: cost = 0.9139
# Epoch 836: cost = 0.9139
# Epoch 837: cost = 0.9138
# Epoch 838: cost = 0.9138
# Epoch 839: cost = 0.9138
# Epoch 840: cost = 0.9138
# Epoch 841: cost = 0.9138
# Epoch 842: cost = 0.9137
# Epoch 843: cost = 0.9137
# Epoch 844: cost = 0.9137
# Epoch 845: cost = 0.9137
# Epoch 846: cost = 0.9137
# Epoch 847: cost = 0.9137
# Epoch 848: cost = 0.9136
# Epoch 849: cost = 0.9136
# Epoch 850: cost = 0.9136
# Epoch 851: cost = 0.9136
# Epoch 852: cost = 0.9136
# Epoch 853: cost = 0.9136
# Epoch 854: cost = 0.9135
# Epoch 855: cost = 0.9135
# Epoch 856: cost = 0.9135
# Epoch 857: cost = 0.9135
# Epoch 858: cost = 0.9135
# Epoch 859: cost = 0.9135
# Epoch 860: cost = 0.9135
# Epoch 861: cost = 0.9135
# Epoch 862: cost = 0.9134
# Epoch 863: cost = 0.9134
# Epoch 864: cost = 0.9134
# Epoch 865: cost = 0.9134
# Epoch 866: cost = 0.9134
# Epoch 867: cost = 0.9134
# Epoch 868: cost = 0.9134
# Epoch 869: cost = 0.9134
# Epoch 870: cost = 0.9133
# Epoch 871: cost = 0.9133
# Epoch 872: cost = 0.9133
# Epoch 873: cost = 0.9133
# Epoch 874: cost = 0.9133
# Epoch 875: cost = 0.9133
# Epoch 876: cost = 0.9133
# Epoch 877: cost = 0.9133
# Epoch 878: cost = 0.9133
# Epoch 879: cost = 0.9133
# Epoch 880: cost = 0.9132
# Epoch 881: cost = 0.9132
# Epoch 882: cost = 0.9132
# Epoch 883: cost = 0.9132
# Epoch 884: cost = 0.9132
# Epoch 885: cost = 0.9132
# Epoch 886: cost = 0.9132
# Epoch 887: cost = 0.9132
# Epoch 888: cost = 0.9132
# Epoch 889: cost = 0.9132
# Epoch 890: cost = 0.9132
# Epoch 891: cost = 0.9132
# Epoch 892: cost = 0.9131
# Epoch 893: cost = 0.9131
# Epoch 894: cost = 0.9131
# Epoch 895: cost = 0.9131
# Epoch 896: cost = 0.9131
# Epoch 897: cost = 0.9131
# Epoch 898: cost = 0.9131
# Epoch 899: cost = 0.9131
# Epoch 900: cost = 0.9131
# Epoch 901: cost = 0.9131
# Epoch 902: cost = 0.9131
# Epoch 903: cost = 0.9131
# Epoch 904: cost = 0.9131
# Epoch 905: cost = 0.9131
# Epoch 906: cost = 0.9131
# Epoch 907: cost = 0.9130
# Epoch 908: cost = 0.9130
# Epoch 909: cost = 0.9130
# Epoch 910: cost = 0.9130
# Epoch 911: cost = 0.9130
# Epoch 912: cost = 0.9130
# Epoch 913: cost = 0.9130
# Epoch 914: cost = 0.9130
# Epoch 915: cost = 0.9130
# Epoch 916: cost = 0.9130
# Epoch 917: cost = 0.9130
# Epoch 918: cost = 0.9130
# Epoch 919: cost = 0.9130
# Epoch 920: cost = 0.9130
# Epoch 921: cost = 0.9130
# Epoch 922: cost = 0.9130
# Epoch 923: cost = 0.9130
# Epoch 924: cost = 0.9130
# Epoch 925: cost = 0.9130
# Epoch 926: cost = 0.9130
# Epoch 927: cost = 0.9130
# Epoch 928: cost = 0.9129
# Epoch 929: cost = 0.9129
# Epoch 930: cost = 0.9129
# Epoch 931: cost = 0.9129
# Epoch 932: cost = 0.9129
# Epoch 933: cost = 0.9129
# Epoch 934: cost = 0.9129
# Epoch 935: cost = 0.9129
# Epoch 936: cost = 0.9129
# Epoch 937: cost = 0.9129
# Epoch 938: cost = 0.9129
# Epoch 939: cost = 0.9129
# Epoch 940: cost = 0.9129
# Epoch 941: cost = 0.9129
# Epoch 942: cost = 0.9129
# Epoch 943: cost = 0.9129
# Epoch 944: cost = 0.9129
# Epoch 945: cost = 0.9129
# Epoch 946: cost = 0.9129
# Epoch 947: cost = 0.9129
# Epoch 948: cost = 0.9129
# Epoch 949: cost = 0.9129
# Epoch 950: cost = 0.9129
# Epoch 951: cost = 0.9129
# Epoch 952: cost = 0.9129
# Epoch 953: cost = 0.9129
# Epoch 954: cost = 0.9129
# Epoch 955: cost = 0.9129
# Epoch 956: cost = 0.9129
# Epoch 957: cost = 0.9129
# Epoch 958: cost = 0.9129
# Epoch 959: cost = 0.9129
# Epoch 960: cost = 0.9129
# Epoch 961: cost = 0.9128
# Epoch 962: cost = 0.9128
# Epoch 963: cost = 0.9128
# Epoch 964: cost = 0.9128
# Epoch 965: cost = 0.9128
# Epoch 966: cost = 0.9128
# Epoch 967: cost = 0.9128
# Epoch 968: cost = 0.9128
# Epoch 969: cost = 0.9128
# Epoch 970: cost = 0.9128
# Epoch 971: cost = 0.9128
# Epoch 972: cost = 0.9128
# Epoch 973: cost = 0.9128
# Epoch 974: cost = 0.9128
# Epoch 975: cost = 0.9128
# Epoch 976: cost = 0.9128
# Epoch 977: cost = 0.9128
# Epoch 978: cost = 0.9128
# Epoch 979: cost = 0.9128
# Epoch 980: cost = 0.9128
# Epoch 981: cost = 0.9128
# Epoch 982: cost = 0.9128
# Epoch 983: cost = 0.9128
# Epoch 984: cost = 0.9128
# Epoch 985: cost = 0.9128
# Epoch 986: cost = 0.9128
# Epoch 987: cost = 0.9128
# Epoch 988: cost = 0.9128
# Epoch 989: cost = 0.9128
# Epoch 990: cost = 0.9128
# Epoch 991: cost = 0.9128
# Epoch 992: cost = 0.9128
# Epoch 993: cost = 0.9128
# Epoch 994: cost = 0.9128
# Epoch 995: cost = 0.9128
# Epoch 996: cost = 0.9128
# Epoch 997: cost = 0.9128
# Epoch 998: cost = 0.9128
# Epoch 999: cost = 0.9128
# Epoch 1000: cost = 0.9128
# Epoch 1001: cost = 0.9128
# Epoch 1002: cost = 0.9128
# Epoch 1003: cost = 0.9128
# Epoch 1004: cost = 0.9128
# Epoch 1005: cost = 0.9128
# Epoch 1006: cost = 0.9128
# Epoch 1007: cost = 0.9128
# Epoch 1008: cost = 0.9128
# Epoch 1009: cost = 0.9128
# Epoch 1010: cost = 0.9128
# Epoch 1011: cost = 0.9128
# Epoch 1012: cost = 0.9128
# Epoch 1013: cost = 0.9128
# Epoch 1014: cost = 0.9128
# Epoch 1015: cost = 0.9128
# Epoch 1016: cost = 0.9128
# Epoch 1017: cost = 0.9128
# Epoch 1018: cost = 0.9128
# Epoch 1019: cost = 0.9128
# Epoch 1020: cost = 0.9128
# Epoch 1021: cost = 0.9128
# Epoch 1022: cost = 0.9128
# Epoch 1023: cost = 0.9128
# Epoch 1024: cost = 0.9128
# Epoch 1025: cost = 0.9128
# Epoch 1026: cost = 0.9128
# Epoch 1027: cost = 0.9128
# Epoch 1028: cost = 0.9128
# Epoch 1029: cost = 0.9128
# Epoch 1030: cost = 0.9128
# Epoch 1031: cost = 0.9128
# Epoch 1032: cost = 0.9128
# Epoch 1033: cost = 0.9128
# Epoch 1034: cost = 0.9128
# Epoch 1035: cost = 0.9128
# Epoch 1036: cost = 0.9128
# Epoch 1037: cost = 0.9128
# Epoch 1038: cost = 0.9128
# Epoch 1039: cost = 0.9128
# Epoch 1040: cost = 0.9128
# Epoch 1041: cost = 0.9128
# Epoch 1042: cost = 0.9128
# Epoch 1043: cost = 0.9128
# Epoch 1044: cost = 0.9128
# Epoch 1045: cost = 0.9127
# Epoch 1046: cost = 0.9127
# Epoch 1047: cost = 0.9127
# Epoch 1048: cost = 0.9127
# Epoch 1049: cost = 0.9127
# Epoch 1050: cost = 0.9127
# Epoch 1051: cost = 0.9127
# Epoch 1052: cost = 0.9127
# Epoch 1053: cost = 0.9127
# Epoch 1054: cost = 0.9127
# Epoch 1055: cost = 0.9127
# Epoch 1056: cost = 0.9127
# Epoch 1057: cost = 0.9127
# Epoch 1058: cost = 0.9127
# Epoch 1059: cost = 0.9127
# Epoch 1060: cost = 0.9127
# Epoch 1061: cost = 0.9127
# Epoch 1062: cost = 0.9127
# Epoch 1063: cost = 0.9127
# Epoch 1064: cost = 0.9127
# Epoch 1065: cost = 0.9127
# Epoch 1066: cost = 0.9127
# Epoch 1067: cost = 0.9127
# Epoch 1068: cost = 0.9127
# Epoch 1069: cost = 0.9127
# Epoch 1070: cost = 0.9127
# Epoch 1071: cost = 0.9127
# Epoch 1072: cost = 0.9127
# Epoch 1073: cost = 0.9127
# Epoch 1074: cost = 0.9127
# Epoch 1075: cost = 0.9127
# Epoch 1076: cost = 0.9127
# Epoch 1077: cost = 0.9127
# Epoch 1078: cost = 0.9127
# Epoch 1079: cost = 0.9127
# Epoch 1080: cost = 0.9127
# Epoch 1081: cost = 0.9127
# Epoch 1082: cost = 0.9127
# Epoch 1083: cost = 0.9127
# Epoch 1084: cost = 0.9127
# Epoch 1085: cost = 0.9127
# Epoch 1086: cost = 0.9127
# Epoch 1087: cost = 0.9127
# Epoch 1088: cost = 0.9127
# Epoch 1089: cost = 0.9127
# Epoch 1090: cost = 0.9127
# Epoch 1091: cost = 0.9127
# Epoch 1092: cost = 0.9127
# Epoch 1093: cost = 0.9127
# Epoch 1094: cost = 0.9127
# Epoch 1095: cost = 0.9127
# Epoch 1096: cost = 0.9127
# Epoch 1097: cost = 0.9127
# Epoch 1098: cost = 0.9127
# Epoch 1099: cost = 0.9127
# Epoch 1100: cost = 0.9127
# Epoch 1101: cost = 0.9127
# Epoch 1102: cost = 0.9127
# Epoch 1103: cost = 0.9127
# Epoch 1104: cost = 0.9127
# Epoch 1105: cost = 0.9127
# Epoch 1106: cost = 0.9127
# Epoch 1107: cost = 0.9127
# Epoch 1108: cost = 0.9127
# Epoch 1109: cost = 0.9127
# Epoch 1110: cost = 0.9127
# Epoch 1111: cost = 0.9127
# Epoch 1112: cost = 0.9127
# Epoch 1113: cost = 0.9127
# Epoch 1114: cost = 0.9127
# Epoch 1115: cost = 0.9127
# Epoch 1116: cost = 0.9127
# Epoch 1117: cost = 0.9127
# Epoch 1118: cost = 0.9127
# Epoch 1119: cost = 0.9127
# Epoch 1120: cost = 0.9127
# Epoch 1121: cost = 0.9127
# Epoch 1122: cost = 0.9127
# Epoch 1123: cost = 0.9127
# Epoch 1124: cost = 0.9127
# Epoch 1125: cost = 0.9127
# Epoch 1126: cost = 0.9127
# Epoch 1127: cost = 0.9127
# Epoch 1128: cost = 0.9127
# Epoch 1129: cost = 0.9127
# Epoch 1130: cost = 0.9127
# Epoch 1131: cost = 0.9127
# Epoch 1132: cost = 0.9127
# Epoch 1133: cost = 0.9127
# Epoch 1134: cost = 0.9127
# Epoch 1135: cost = 0.9127
# Epoch 1136: cost = 0.9127
# Epoch 1137: cost = 0.9127
# Epoch 1138: cost = 0.9127
# Epoch 1139: cost = 0.9127
# Epoch 1140: cost = 0.9127
# Epoch 1141: cost = 0.9127
# Epoch 1142: cost = 0.9127
# Epoch 1143: cost = 0.9127
# Epoch 1144: cost = 0.9127
# Epoch 1145: cost = 0.9127
# Epoch 1146: cost = 0.9127
# Epoch 1147: cost = 0.9127
# Epoch 1148: cost = 0.9127
# Epoch 1149: cost = 0.9127
# Epoch 1150: cost = 0.9127
# Epoch 1151: cost = 0.9127
# Epoch 1152: cost = 0.9127
# Epoch 1153: cost = 0.9127
# Epoch 1154: cost = 0.9127
# Epoch 1155: cost = 0.9127
# Epoch 1156: cost = 0.9127
# Epoch 1157: cost = 0.9127
# Epoch 1158: cost = 0.9127
# Epoch 1159: cost = 0.9127
# Epoch 1160: cost = 0.9127
# Epoch 1161: cost = 0.9127
# Epoch 1162: cost = 0.9127
# Epoch 1163: cost = 0.9127
# Epoch 1164: cost = 0.9127
# Epoch 1165: cost = 0.9127
# Epoch 1166: cost = 0.9127
# Epoch 1167: cost = 0.9127
# Epoch 1168: cost = 0.9127
# Epoch 1169: cost = 0.9127
# Epoch 1170: cost = 0.9127
# Epoch 1171: cost = 0.9127
# Epoch 1172: cost = 0.9127
# Epoch 1173: cost = 0.9127
# Epoch 1174: cost = 0.9127
# Epoch 1175: cost = 0.9127
# Epoch 1176: cost = 0.9127
# Epoch 1177: cost = 0.9127
# Epoch 1178: cost = 0.9127
# Epoch 1179: cost = 0.9127
# Epoch 1180: cost = 0.9127
# Epoch 1181: cost = 0.9127
# Epoch 1182: cost = 0.9127
# Epoch 1183: cost = 0.9127
# Epoch 1184: cost = 0.9127
# Epoch 1185: cost = 0.9127
# Epoch 1186: cost = 0.9127
# Epoch 1187: cost = 0.9127
# Epoch 1188: cost = 0.9127
# Epoch 1189: cost = 0.9127
# Epoch 1190: cost = 0.9127
# Epoch 1191: cost = 0.9127
# Epoch 1192: cost = 0.9127
# Epoch 1193: cost = 0.9127
# Epoch 1194: cost = 0.9127
# Epoch 1195: cost = 0.9127
# Epoch 1196: cost = 0.9127
# Epoch 1197: cost = 0.9127
# Epoch 1198: cost = 0.9127
# Epoch 1199: cost = 0.9127
# Epoch 1200: cost = 0.9127
# Epoch 1201: cost = 0.9127
# Epoch 1202: cost = 0.9127
# Epoch 1203: cost = 0.9127
# Epoch 1204: cost = 0.9127
# Epoch 1205: cost = 0.9127
# Epoch 1206: cost = 0.9127
# Epoch 1207: cost = 0.9127
# Epoch 1208: cost = 0.9127
# Epoch 1209: cost = 0.9127
# Epoch 1210: cost = 0.9127
# Epoch 1211: cost = 0.9127
# Epoch 1212: cost = 0.9127
# Epoch 1213: cost = 0.9127
# Epoch 1214: cost = 0.9127
# Epoch 1215: cost = 0.9127
# Epoch 1216: cost = 0.9127
# Epoch 1217: cost = 0.9127
# Epoch 1218: cost = 0.9127
# Epoch 1219: cost = 0.9127
# Epoch 1220: cost = 0.9127
# Epoch 1221: cost = 0.9127
# Epoch 1222: cost = 0.9127
# Epoch 1223: cost = 0.9127
# Epoch 1224: cost = 0.9127
# Epoch 1225: cost = 0.9127
# Epoch 1226: cost = 0.9127
# Epoch 1227: cost = 0.9127
# Epoch 1228: cost = 0.9127
# Epoch 1229: cost = 0.9127
# Epoch 1230: cost = 0.9127
# Epoch 1231: cost = 0.9127
# Epoch 1232: cost = 0.9127
# Epoch 1233: cost = 0.9127
# Epoch 1234: cost = 0.9127
# Epoch 1235: cost = 0.9127
# Epoch 1236: cost = 0.9127
# Epoch 1237: cost = 0.9127
# Epoch 1238: cost = 0.9127
# Epoch 1239: cost = 0.9127
# Epoch 1240: cost = 0.9127
# Epoch 1241: cost = 0.9127
# Epoch 1242: cost = 0.9127
# Epoch 1243: cost = 0.9127
# Epoch 1244: cost = 0.9127
# Epoch 1245: cost = 0.9127
# Epoch 1246: cost = 0.9127
# Epoch 1247: cost = 0.9127
# Epoch 1248: cost = 0.9127
# Epoch 1249: cost = 0.9127
# Epoch 1250: cost = 0.9127
# Epoch 1251: cost = 0.9127
# Epoch 1252: cost = 0.9127
# Epoch 1253: cost = 0.9127
# Epoch 1254: cost = 0.9127
# Epoch 1255: cost = 0.9127
# Epoch 1256: cost = 0.9127
# Epoch 1257: cost = 0.9127
# Epoch 1258: cost = 0.9127
# Epoch 1259: cost = 0.9127
# Epoch 1260: cost = 0.9127
# Epoch 1261: cost = 0.9127
# Epoch 1262: cost = 0.9127
# Epoch 1263: cost = 0.9127
# Epoch 1264: cost = 0.9127
# Epoch 1265: cost = 0.9127
# Epoch 1266: cost = 0.9127
# Epoch 1267: cost = 0.9127
# Epoch 1268: cost = 0.9127
# Epoch 1269: cost = 0.9127
# Epoch 1270: cost = 0.9127
# Epoch 1271: cost = 0.9127
# Epoch 1272: cost = 0.9127
# Epoch 1273: cost = 0.9127
# Epoch 1274: cost = 0.9127
# Epoch 1275: cost = 0.9127
# Epoch 1276: cost = 0.9127
# Epoch 1277: cost = 0.9127
# Epoch 1278: cost = 0.9127
# Epoch 1279: cost = 0.9127
# Epoch 1280: cost = 0.9127
# Epoch 1281: cost = 0.9127
# Epoch 1282: cost = 0.9127
# Epoch 1283: cost = 0.9127
# Epoch 1284: cost = 0.9127
# Epoch 1285: cost = 0.9127
# Epoch 1286: cost = 0.9127
# Epoch 1287: cost = 0.9127
# Epoch 1288: cost = 0.9127
# Epoch 1289: cost = 0.9127
# Epoch 1290: cost = 0.9127
# Epoch 1291: cost = 0.9127
# Epoch 1292: cost = 0.9127
# Epoch 1293: cost = 0.9127
# Epoch 1294: cost = 0.9127
# Epoch 1295: cost = 0.9127
# Epoch 1296: cost = 0.9127
# Epoch 1297: cost = 0.9127
# Epoch 1298: cost = 0.9127
# Epoch 1299: cost = 0.9127
# Epoch 1300: cost = 0.9127
# Epoch 1301: cost = 0.9127
# Epoch 1302: cost = 0.9127
# Epoch 1303: cost = 0.9127
# Epoch 1304: cost = 0.9127
# Epoch 1305: cost = 0.9127
# Epoch 1306: cost = 0.9127
# Epoch 1307: cost = 0.9127
# Epoch 1308: cost = 0.9127
# Epoch 1309: cost = 0.9127
# Epoch 1310: cost = 0.9127
# Epoch 1311: cost = 0.9127
# Epoch 1312: cost = 0.9127
# Epoch 1313: cost = 0.9127
# Epoch 1314: cost = 0.9127
# Epoch 1315: cost = 0.9127
# Epoch 1316: cost = 0.9127
# Epoch 1317: cost = 0.9127
# Epoch 1318: cost = 0.9127
# Epoch 1319: cost = 0.9127
# Epoch 1320: cost = 0.9127
# Epoch 1321: cost = 0.9127
# Epoch 1322: cost = 0.9127
# Epoch 1323: cost = 0.9127
# Epoch 1324: cost = 0.9127
# Epoch 1325: cost = 0.9127
# Epoch 1326: cost = 0.9127
# Epoch 1327: cost = 0.9127
# Epoch 1328: cost = 0.9127
# Epoch 1329: cost = 0.9127
# Epoch 1330: cost = 0.9127
# Epoch 1331: cost = 0.9127
# Epoch 1332: cost = 0.9127
# Epoch 1333: cost = 0.9127
# Epoch 1334: cost = 0.9127
# Epoch 1335: cost = 0.9127
# Epoch 1336: cost = 0.9127
# Epoch 1337: cost = 0.9127
# Epoch 1338: cost = 0.9127
# Epoch 1339: cost = 0.9127
# Epoch 1340: cost = 0.9127
# Epoch 1341: cost = 0.9127
# Epoch 1342: cost = 0.9127
# Epoch 1343: cost = 0.9127
# Epoch 1344: cost = 0.9127
# Epoch 1345: cost = 0.9127
# Epoch 1346: cost = 0.9127
# Epoch 1347: cost = 0.9127
# Epoch 1348: cost = 0.9127
# Epoch 1349: cost = 0.9127
# Epoch 1350: cost = 0.9127
# Epoch 1351: cost = 0.9127
# Epoch 1352: cost = 0.9127
# Epoch 1353: cost = 0.9127
# Epoch 1354: cost = 0.9127
# Epoch 1355: cost = 0.9127
# Epoch 1356: cost = 0.9127
# Epoch 1357: cost = 0.9127
# Epoch 1358: cost = 0.9127
# Epoch 1359: cost = 0.9127
# Epoch 1360: cost = 0.9127
# Epoch 1361: cost = 0.9127
# Epoch 1362: cost = 0.9127
# Epoch 1363: cost = 0.9127
# Epoch 1364: cost = 0.9127
# Epoch 1365: cost = 0.9127
# Epoch 1366: cost = 0.9127
# Epoch 1367: cost = 0.9127
# Epoch 1368: cost = 0.9127
# Epoch 1369: cost = 0.9127
# Epoch 1370: cost = 0.9127
# Epoch 1371: cost = 0.9127
# Epoch 1372: cost = 0.9127
# Epoch 1373: cost = 0.9127
# Epoch 1374: cost = 0.9127
# Epoch 1375: cost = 0.9127
# Epoch 1376: cost = 0.9127
# Epoch 1377: cost = 0.9127
# Epoch 1378: cost = 0.9127
# Epoch 1379: cost = 0.9127
# Epoch 1380: cost = 0.9127
# Epoch 1381: cost = 0.9127
# Epoch 1382: cost = 0.9127
# Epoch 1383: cost = 0.9127
# Epoch 1384: cost = 0.9127
# Epoch 1385: cost = 0.9127
# Epoch 1386: cost = 0.9127
# Epoch 1387: cost = 0.9127
# Epoch 1388: cost = 0.9127
# Epoch 1389: cost = 0.9127
# Epoch 1390: cost = 0.9127
# Epoch 1391: cost = 0.9127
# Epoch 1392: cost = 0.9127
# Epoch 1393: cost = 0.9127
# Epoch 1394: cost = 0.9127
# Epoch 1395: cost = 0.9127
# Epoch 1396: cost = 0.9127
# Epoch 1397: cost = 0.9127
# Epoch 1398: cost = 0.9127
# Epoch 1399: cost = 0.9127
# Epoch 1400: cost = 0.9127
# Epoch 1401: cost = 0.9127
# Epoch 1402: cost = 0.9127
# Epoch 1403: cost = 0.9127
# Epoch 1404: cost = 0.9127
# Epoch 1405: cost = 0.9127
# Epoch 1406: cost = 0.9127
# Epoch 1407: cost = 0.9127
# Epoch 1408: cost = 0.9127
# Epoch 1409: cost = 0.9127
# Epoch 1410: cost = 0.9127
# Epoch 1411: cost = 0.9127
# Epoch 1412: cost = 0.9127
# Epoch 1413: cost = 0.9127
# Epoch 1414: cost = 0.9127
# Epoch 1415: cost = 0.9127
# Epoch 1416: cost = 0.9127
# Epoch 1417: cost = 0.9127
# Epoch 1418: cost = 0.9127
# Epoch 1419: cost = 0.9127
# Epoch 1420: cost = 0.9127
# Epoch 1421: cost = 0.9127
# Epoch 1422: cost = 0.9127
# Epoch 1423: cost = 0.9127
# Epoch 1424: cost = 0.9127
# Epoch 1425: cost = 0.9127
# Epoch 1426: cost = 0.9127
# Epoch 1427: cost = 0.9127
# Epoch 1428: cost = 0.9127
# Epoch 1429: cost = 0.9127
# Epoch 1430: cost = 0.9127
# Epoch 1431: cost = 0.9127
# Epoch 1432: cost = 0.9127
# Epoch 1433: cost = 0.9127
# Epoch 1434: cost = 0.9127
# Epoch 1435: cost = 0.9127
# Epoch 1436: cost = 0.9127
# Epoch 1437: cost = 0.9127
# Epoch 1438: cost = 0.9127
# Epoch 1439: cost = 0.9127
# Epoch 1440: cost = 0.9127
# Epoch 1441: cost = 0.9127
# Epoch 1442: cost = 0.9127
# Epoch 1443: cost = 0.9127
# Epoch 1444: cost = 0.9127
# Epoch 1445: cost = 0.9127
# Epoch 1446: cost = 0.9127
# Epoch 1447: cost = 0.9127
# Epoch 1448: cost = 0.9127
# Epoch 1449: cost = 0.9127
# Epoch 1450: cost = 0.9127
# Epoch 1451: cost = 0.9127
# Epoch 1452: cost = 0.9127
# Epoch 1453: cost = 0.9127
# Epoch 1454: cost = 0.9127
# Epoch 1455: cost = 0.9127
# Epoch 1456: cost = 0.9127
# Epoch 1457: cost = 0.9127
# Epoch 1458: cost = 0.9127
# Epoch 1459: cost = 0.9127
# Epoch 1460: cost = 0.9127
# Epoch 1461: cost = 0.9127
# Epoch 1462: cost = 0.9127
# Epoch 1463: cost = 0.9127
# Epoch 1464: cost = 0.9127
# Epoch 1465: cost = 0.9127
# Epoch 1466: cost = 0.9127
# Epoch 1467: cost = 0.9127
# Epoch 1468: cost = 0.9127
# Epoch 1469: cost = 0.9127
# Epoch 1470: cost = 0.9127
# Epoch 1471: cost = 0.9127
# Epoch 1472: cost = 0.9127
# Epoch 1473: cost = 0.9127
# Epoch 1474: cost = 0.9127
# Epoch 1475: cost = 0.9127
# Epoch 1476: cost = 0.9127
# Epoch 1477: cost = 0.9127
# Epoch 1478: cost = 0.9127
# Epoch 1479: cost = 0.9127
# Epoch 1480: cost = 0.9127
# Epoch 1481: cost = 0.9127
# Epoch 1482: cost = 0.9127
# Epoch 1483: cost = 0.9127
# Epoch 1484: cost = 0.9127
# Epoch 1485: cost = 0.9127
# Epoch 1486: cost = 0.9127
# Epoch 1487: cost = 0.9127
# Epoch 1488: cost = 0.9127
# Epoch 1489: cost = 0.9127
# Epoch 1490: cost = 0.9127
# Epoch 1491: cost = 0.9127
# Epoch 1492: cost = 0.9127
# Epoch 1493: cost = 0.9127
# Epoch 1494: cost = 0.9127
# Epoch 1495: cost = 0.9127
# Epoch 1496: cost = 0.9127
# Epoch 1497: cost = 0.9127
# Epoch 1498: cost = 0.9127
# Epoch 1499: cost = 0.9127

# %%
y_preds = gd_lr.predict(X_test)

# %%
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred)**2))

def r2_score(y_true, y_pred):
    ss_lr = np.sum((y_true - y_pred)**2)
    ss_m = np.sum((y_true - np.mean(y_true))**2)
    return 1 - ss_lr/ss_m

# %%
print(rmse(y_test, y_preds))
print(r2_score(y_test, y_preds))
# Out:
# 104.27666921163883
# -38.77184511880347

# %% [markdown]
# # Stochastic Gradient Descent
# In the above formulation (of batch gradient descent), we have to calculate the gradient using every row of the design matrix during each training epoch. When the dataset gets large, that can become pretty slow. On top of that, since we need to load the entire training set into memory for every pass, this approach can run into memory issues if the dataset is huge.
#
# Each individual gradient might not point exactly in the right direction, but on average, they do. Since the expected value of all these gradients equals the true gradient, repeating the process over many epochs makes the updates collectively move in the correct direction. In other words, the path traced by successive updates gradually aligns with the true gradient because, over time, we’re effectively averaging out the noise in each step.
#
# Hence,  this algorithm is much less regular than Batch Gradient Descent: instead of gently decreasing until it reaches the minimum, the cost function will bounce up and down, decreasing only on average. Over time it will end up very close to the minimum, but once it gets there it will
# continue to bounce around, never settling down. So once the algorithm stops, the final parameter values are good, but not optimal.
#
# When the cost function is very irregular, this can actually help the algorithm jump out of local minima, so Stochastic Gradient Descent has a better chance of finding the global minimum than Batch Gradient Descent does in such a case.

# %%
import random

class SGDLinearRegressor:
    def __init__(self, learning_rate: float = 0.01, epochs: int = 200):
        self.alpha = learning_rate
        self.epochs = epochs
        self.beta = None
        self.m = None

    def _validate_input(self, X, y=None):
        """Internal helper for checking and preparing input arrays."""
        X = np.asarray(X, dtype=float)
    
        # If y is provided (fit case)
        if y is not None:
            y = np.asarray(y, dtype=float).reshape(-1, 1)
    
            if X.size == 0 or y.size == 0:
                raise ValueError("X and y must be non-empty.")
            if X.shape[0] != y.shape[0]:
                raise ValueError("X and y must have the same number of samples.")
            if not np.isfinite(X).all() or not np.isfinite(y).all():
                raise ValueError("Inputs contain NaN or infinite values.")
    
        else:
            # Only validate X (predict case)
            if X.size == 0:
                raise ValueError("X must be non-empty.")
            if not np.isfinite(X).all():
                raise ValueError("X contains NaN or infinite values.")
    
        if X.ndim == 1:
            X = X.reshape(-1, 1)
    
        # Return both for fit(), only X for predict()
        return (X, y) if y is not None else X

    def fit(self, X_train: ArrayLike, y_train: ArrayLike):
        X, y = self._validate_input(X_train, y_train)
        n, self.m = X.shape
        X_c = np.concatenate((np.ones((n, 1)), X), axis=1)
        self.beta = np.zeros((self.m + 1, 1))

        for _ in range(self.epochs):
            for j in range(n):
                idx = np.random.randint(0, n)  # pick a random index
                x_i = X_c[idx:idx+1]           # shape (1, m+1)
                y_i = y[idx:idx+1]             # shape (1, 1)
        
                # Compute the residual for this sample
                error_i = y_i - x_i @ self.beta
        
                # Gradient for this sample (no need to divide by n — it’s stochastic!)
                grad_i = -x_i.T @ error_i
        
                # Parameter update
                self.beta -= self.alpha * grad_i
        
                return self
        
    def predict(self, X_test: ArrayLike):

        if self.beta is None:
            raise ValueError("Model has not been fitted yet.")
        
        X = self._validate_input(X_test) 
        n = X.shape[0]
        X_c = np.concatenate((np.ones((n, 1)), X), axis=1)
        return X_c @ self.beta

# %%
custom_sgd = SGDLinearRegressor(learning_rate=0.01, epochs=100)
custom_sgd.fit(X_train, y_train)

# %%
y_preds = custom_sgd.predict(X_test)

# %%
print(rmse(y_test, y_preds))
print(r2_score(y_test, y_preds))
# Out:
# 74.10787968719626
# -19.087700007349177

# %%
from sklearn.linear_model import SGDRegressor
reg = SGDRegressor(max_iter=100, learning_rate='constant', eta0=0.01)
reg.fit(X_train, y_train)
# Out:
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_preds = reg.predict(X_test)
print(rmse(y_test, y_preds))
print(r2_score(y_test, y_preds))
# Out:
# 1.270735221922141
# 0.999704687671324
